# %% [markdown]
# #Import library

# %%
import os
import glob
from IPython.display import Image, display

# %% [markdown]
# #Checking access to GPU

# %%
# !pip install nvidia-smi
# !nvidia-smi

# %% [markdown]
# #Mounted Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# #Installing YOLOv8

# %%
# !pip install ultralytics
# !pip install -U ultralytics

# %% [markdown]
# #Check if YOLOv8 is installed

# %%
import ultralytics
ultralytics.checks()

# %% [markdown]
# #Start train

# %%
# !yolo mode=train task=detect model=path/to/dataset/train2/yolov8n.pt data=path/to/dataset/data.yaml epochs=10 imgsz=640 save=True project='path/to/dataset/'

# %% [markdown]
# Train again with updated dataset

# %%
# !yolo mode=train resume=True task=detect model=path/to/dataset/train2/weights/best.pt data=path/to/dataset/data.yaml epochs=6 imgsz=640

# %% [markdown]
# #Print confusion matrix

# %%
Image(filename=f"path/to/dataset/train2/confusion_matrix.png")

# %% [markdown]
# #Check model prevision

# %%
Image(filename=f"path/to/dataset/train2/val_batch2_pred.jpg", height=500)

# %% [markdown]
# #Printing the train and validation loss

# %%
Image(filename=f"path/to/dataset/train2/results.png", width=600)

# %% [markdown]
# #Validate custom model

# %%
# !yolo task=detect mode=val model='path/to/dataset/train2/weights/best.pt' data=/path/to/dataset/data.yaml

# %% [markdown]
# #Run predict.py script

# %%
# !yolo task=detect mode=predict model=path/to/dataset/train2/best.pt conf=0.2 source="path/to/video/folder/video.mp4" save=True project='path/to/dataset/video/path/save/'
